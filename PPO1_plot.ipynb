# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_mod = pd.read_csv('run_BreakoutNoFrameskip-v4-25_PPO1_1-tag-episode_reward.csv')
df_base = pd.read_csv('run_BreakoutNoFrameskip-v4-9_PPO1_1-tag-episode_reward.csv')

win = 100
fig = plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.ylim((0, 2.5))
plt.suptitle("Reward During Training in Breakout")
plt.title("(Reward calculated using Rolling Mean with Window = {})".format(win))
plt.xlabel("Step")
plt.ylabel("Average Episode Reward")
plt.plot(df_mod.Step, df_mod.Value.rolling(win, center=False).mean())
plt.plot(df_base.Step, df_base.Value.rolling(win, center=False).mean())
plt.gca().legend(('Modified','Base'))
plt.show()

# %%
df_mod = pd.read_csv('data/run_BreakoutNoFrameskip-v4-25_PPO1_1-tag-input_info_advantage.csv')
df_base = pd.read_csv('data/run_BreakoutNoFrameskip-v4-9_PPO1_1-tag-input_info_advantage.csv')

win = 750
fig = plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.ylim((0, 2.5))
plt.suptitle("Advantage")
plt.title("(Calculated using Rolling Mean with Window = {})".format(win))
plt.xlabel("Step")
plt.ylabel("Average Episode Advantage")
plt.plot(df_mod.Step, df_mod.Value.rolling(win, center=False).mean())
plt.plot(df_base.Step, df_base.Value.rolling(win, center=False).mean())
plt.gca().legend(('Modified','Base'))
plt.show()

# %%
df_mod = pd.read_csv('data/run_BreakoutNoFrameskip-v4-25_PPO1_1-tag-input_info_discounted_rewards.csv')
df_base = pd.read_csv('data/run_BreakoutNoFrameskip-v4-9_PPO1_1-tag-input_info_discounted_rewards.csv')

win = 10
fig = plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.ylim((0, 2.5))
plt.suptitle("Discounted Rewards")
plt.title("(Calculated using Rolling Mean with Window = {})".format(win))
plt.xlabel("Step")
plt.ylabel("Average Episode Discounted Reward")
plt.plot(df_mod.Step, df_mod.Value.rolling(win, center=False).mean())
plt.plot(df_base.Step, df_base.Value.rolling(win, center=False).mean())
plt.gca().legend(('Modified','Base'))
plt.show()

# %%
df_mod = pd.read_csv('data/run_BreakoutNoFrameskip-v4-25_PPO1_1-tag-loss_approximate_kullback-leiber.csv')
df_base = pd.read_csv('data/run_BreakoutNoFrameskip-v4-9_PPO1_1-tag-loss_approximate_kullback-leiber.csv')

win = 100
fig = plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.ylim((0, 2.5))
plt.suptitle("Approximate Kullback–Leibler Divergence")
plt.title("(Calculated using Rolling Mean with Window = {})".format(win))
plt.xlabel("Step")
plt.ylabel("Average Episode KL Divergence")
plt.plot(df_mod.Step, df_mod.Value.rolling(win, center=False).mean())
plt.plot(df_base.Step, df_base.Value.rolling(win, center=False).mean())
plt.gca().legend(('Modified','Base'))
plt.show()

# %%
df_mod = pd.read_csv('data/run_BreakoutNoFrameskip-v4-25_PPO1_1-tag-loss_entropy_loss.csv')
df_base = pd.read_csv('data/run_BreakoutNoFrameskip-v4-9_PPO1_1-tag-loss_entropy_loss.csv')

win = 25
fig = plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.ylim((0, 2.5))
plt.suptitle("Entropy Loss")
plt.title("(Calculated using Rolling Mean with Window = {})".format(win))
plt.xlabel("Step")
plt.ylabel("Average Episode Entropy Loss")
plt.plot(df_mod.Step, df_mod.Value.rolling(win, center=False).mean())
plt.plot(df_base.Step, df_base.Value.rolling(win, center=False).mean())
plt.gca().legend(('Modified','Base'))
plt.show()

# %%
df_mod = pd.read_csv('data/run_BreakoutNoFrameskip-v4-25_PPO1_1-tag-loss_loss.csv')
df_base = pd.read_csv('data/run_BreakoutNoFrameskip-v4-9_PPO1_1-tag-loss_loss.csv')

win = 10
fig = plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.ylim((0, 2.5))
plt.suptitle("Loss")
plt.title("(Calculated using Rolling Mean with Window = {})".format(win))
plt.xlabel("Step")
plt.ylabel("Average Episode Loss")
plt.plot(df_mod.Step, df_mod.Value.rolling(win, center=False).mean())
plt.plot(df_base.Step, df_base.Value.rolling(win, center=False).mean())
plt.gca().legend(('Modified','Base'))
plt.show()

# %%
df_mod = pd.read_csv('data/run_BreakoutNoFrameskip-v4-25_PPO1_1-tag-loss_policy_gradient_loss.csv')
df_base = pd.read_csv('data/run_BreakoutNoFrameskip-v4-9_PPO1_1-tag-loss_policy_gradient_loss.csv')

win = 100
fig = plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.ylim((0, 2.5))
plt.suptitle("Policy Gradient Loss")
plt.title("(Calculated using Rolling Mean with Window = {})".format(win))
plt.xlabel("Step")
plt.ylabel("Average Episode Loss")
plt.plot(df_mod.Step, df_mod.Value.rolling(win, center=False).mean())
plt.plot(df_base.Step, df_base.Value.rolling(win, center=False).mean())
plt.gca().legend(('Modified','Base'))
plt.show()

# %%
df_mod = pd.read_csv('data/run_BreakoutNoFrameskip-v4-25_PPO1_1-tag-loss_value_function_loss.csv')
df_base = pd.read_csv('data/run_BreakoutNoFrameskip-v4-9_PPO1_1-tag-loss_value_function_loss.csv')

win = 10
fig = plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.ylim((0, 2.5))
plt.suptitle("Value Loss")
plt.title("(Calculated using Rolling Mean with Window = {})".format(win))
plt.xlabel("Step")
plt.ylabel("Average Episode Value Loss")
plt.plot(df_mod.Step, df_mod.Value.rolling(win, center=False).mean())
plt.plot(df_base.Step, df_base.Value.rolling(win, center=False).mean())
plt.gca().legend(('Modified','Base'))
plt.show()
